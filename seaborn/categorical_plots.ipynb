# %% [markdown]
# ## Categorical plots

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1. catplot
# > Figure-level interface for drawing categorical plots onto a FacetGrid.
#
# ```
# seaborn.catplot(*, x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x7fecadf1cee0>, ci=95, n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)¶
# ```
# > [References](https://seaborn.pydata.org/generated/seaborn.catplot.html#seaborn.catplot)

# %%
exercise = sns.load_dataset("exercise")
exercise[:2]
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest

# %%
sns.catplot(data=exercise, hue="kind", x="time", y="pulse")
plt.show()

# %%
sns.catplot(data=exercise, hue="kind", x="time", y="pulse", kind="swarm")
plt.show()

# %%
sns.catplot(data=exercise, hue="kind", x="time", y="pulse", kind="swarm", col="diet")
plt.show()

# %% [markdown]
# ### 2. stripplot
# > Draw a scatterplot where one variable is categorical.
#
# ```
# seaborn.stripplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, jitter=True, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
# ```

# %%
tips = sns.load_dataset("tips")
tips[:7]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2

# %%
sns.stripplot(x="total_bill", data=tips)
plt.show()

# %%
sns.stripplot(x="total_bill", data=tips, y="tip")
plt.show()

# %%
sns.stripplot(x="total_bill", data=tips, y="tip", hue="sex",)
plt.show()

# %% [markdown]
# ### 3. swarnplot()
# ```
# seaborn.swarmplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
# ```
# >Draw a categorical scatterplot with non-overlapping points.

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)
plt.show()

# %% [markdown]
# ### boxplot()
# >  Draw a box plot to show distributions with respect to categories.
#
# ```
# seaborn.boxplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)
# ```

# %%
sns.boxplot(data=tips, x="day",y="total_bill", hue="sex" )
plt.show()

# %% [markdown]
# ### violinplot()
# ```
# seaborn.violinplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.8, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None, palette=None, saturation=0.75, ax=None, **kwargs)
#
# ```
# >Draw a combination of boxplot and kernel density estimate.

# %%
sns.violinplot(data=tips, x="day",y="total_bill", hue="sex" )
plt.show()

# %%
sns.violinplot(data=tips, x="total_bill")
plt.show()

# %% [markdown]
# ### pointplot
# ```
# seaborn.pointplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x7fecadf1cee0>, ci=95, n_boot=1000, units=None, seed=None, markers='o', linestyles='-', dodge=False, join=True, scale=1, orient=None, color=None, palette=None, errwidth=None, capsize=None, ax=None, **kwargs)
#
# ```
# > Show point estimates and confidence intervals using scatter plot glyphs.

# %%
sns.pointplot(x="time", y="total_bill", data=tips)
plt.show()

# %%
sns.pointplot(x="time", y="total_bill", data=tips, hue="smoker")
plt.show()

# %%
sns.pointplot(x="time", y="total_bill", data=tips, hue="smoker", markers=["o", "x"],
                   linestyles=["-", "--"])
plt.show()

# %% [markdown]
# ### barplot
# ```
# seaborn.barplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x7fecadf1cee0>, ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)¶
# ```
# >Show point estimates and confidence intervals as rectangular bars.

# %%
sns.barplot(x="sex", y="total_bill", data=tips)
plt.show()

# %%
a = np.random.randint(0, 100, 10)
b = np.random.rand(10)

# %%
sns.barplot(x=a, y=b)
plt.show()

# %% [markdown]
# ### countplot
#
# ```
# seaborn.countplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)
#
# ```
# > Show the counts of observations in each categorical bin using bars.

# %%
titanic = sns.load_dataset("titanic")
sns.countplot(x="class", hue="who", data=titanic)
plt.show()

# %%
titanic[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
sns.countplot(x="class", hue="alone", data=titanic)
plt.show()
